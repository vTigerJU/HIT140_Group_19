# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the dataset
dataset3 = pd.read_csv('dataset3.csv')

# %%
df = dataset3.drop(['ID'], axis = 1)
df.describe()
# Out:
#                 Optm           Usef           Relx           Intp  \
# count  102580.000000  102580.000000  102580.000000  102580.000000
# mean        3.276087       3.107428       3.097826       3.272314
# std         0.997897       0.953128       1.015441       1.018537
# min         1.000000       1.000000       1.000000       1.000000
# 25%         3.000000       3.000000       2.000000       3.000000
# 50%         3.000000       3.000000       3.000000       3.000000
# 75%         4.000000       4.000000       4.000000       4.000000
# max         5.000000       5.000000       5.000000       5.000000
#
#                 Engs         Dealpr         Thcklr         Goodme  \
# count  102580.000000  102580.000000  102580.000000  102580.000000
# mean        3.048050       3.369448       3.488039       3.273250
# std         1.076483       1.049365       1.018274       1.126084
# min         1.000000       1.000000       1.000000       1.000000
# ...

# %%
df.mode()
# Out:
#    Optm  Usef  Relx  Intp  Engs  Dealpr  Thcklr  Goodme  Clsep  Conf  Mkmind  \
# 0     3     3     3     4     3       4       4       4      4     4       4
#
#    Loved  Intthg  Cheer
# 0      5       4      4

# %%
# Well-being indicator labels for descriptive analysis
wellbeing_labels = {
    "Optm": "Feeling optimistic about the future",
    "Usef": "Feeling useful",
    "Relx": "Feeling relaxed",
    "Intp": "Feeling interested in other people",
    "Engs": "Having energy to spare",
    "Dealpr": "Dealing with problems well",
    "Thcklr": "Thinking clearly",
    "Goodme": "Feeling good about myself",
    "Clsep": "Feeling close to other people",
    "Conf": "Feeling confident",
    "Mkmind": "Making up my own mind about things",
    "Loved": "Feeling loved",
    "Intthg": "Interested in new things",
    "Cheer": "Feeling cheerful"
}

# %%
# Feeling optimistic about the future
plt.figure(figsize=(8, 6))
plt.hist(dataset3['Optm'], bins=5, edgecolor='black')
plt.title("Feeling optimistic about the future")
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.show()

# %%
# Feeling useful
plt.figure(figsize=(8, 6))
plt.hist(dataset3['Usef'], bins=5, edgecolor='black')
plt.title("Feeling useful")
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.show()

# %%
# Feeling relaxed
plt.figure(figsize=(8, 6))
plt.hist(dataset3['Relx'], bins=5, edgecolor='black')
plt.title("Feeling relaxed")
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.show()

# %%
# Feeling interested in other people
plt.figure(figsize=(8, 6))
plt.hist(dataset3['Intp'], bins=5, edgecolor='black')
plt.title("Feeling interested in other people")
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.show()

# %%
# Having energy to spare
plt.figure(figsize=(8, 6))
plt.hist(dataset3['Engs'], bins=5, edgecolor='black')
plt.title("Having energy to spare")
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.show()

# %%
# Dealing with problems well
plt.figure(figsize=(8, 6))
plt.hist(dataset3['Dealpr'], bins=5, edgecolor='black')
plt.title("Dealing with problems well")
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.show()

# %%
# Thinking clearly
plt.figure(figsize=(8, 6))
plt.hist(dataset3['Thcklr'], bins=5, edgecolor='black')
plt.title("Thinking clearly")
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.show()

# %%
# Feeling good about myself
plt.figure(figsize=(8, 6))
plt.hist(dataset3['Goodme'], bins=5, edgecolor='black')
plt.title("Feeling good about myself")
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.show()

# %%
# Feeling close to other people
plt.figure(figsize=(8, 6))
plt.hist(dataset3['Clsep'], bins=5, edgecolor='black')
plt.title("Feeling close to other people")
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.show()

# %%
# Feeling confident
plt.figure(figsize=(8, 6))
plt.hist(dataset3['Conf'], bins=5, edgecolor='black')
plt.title("Feeling confident")
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.show()

# %%
# Making up my own mind about things
plt.figure(figsize=(8, 6))
plt.hist(dataset3['Mkmind'], bins=5, edgecolor='black')
plt.title("Making up my own mind about things")
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.show()

# %%
# Feeling loved
plt.figure(figsize=(8, 6))
plt.hist(dataset3['Loved'], bins=5, edgecolor='black')
plt.title("Feeling loved")
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.show()

# %%
# Interested in new things
plt.figure(figsize=(8, 6))
plt.hist(dataset3['Intthg'], bins=5, edgecolor='black')
plt.title("Interested in new things")
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.show()

# %%
# Feeling cheerful
plt.figure(figsize=(8, 6))
plt.hist(dataset3['Cheer'], bins=5, edgecolor='black')
plt.title("Feeling cheerful")
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.show()
