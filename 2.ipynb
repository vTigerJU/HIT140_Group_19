# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Load datasets
df1 = pd.read_csv('dataset1.csv')
df2 = pd.read_csv('dataset2.csv')
df3 = pd.read_csv('dataset3.csv')

# %%
# Merge df1 (demographics) and df2 (screen time)
df = pd.merge(df1, df2, on='ID', how='inner')
df
# Out:
#              ID  gender  minority  deprived  C_we  C_wk  G_we  G_wk  S_we  \
# 0       1087192       0         0         0   2.0   0.5   0.5   0.5   1.0
# 1       1087195       0         0         0   2.0   1.0   0.0   0.0   3.0
# 2       1087205       0         0         0   1.0   0.5   0.0   0.0   0.5
# 3       1087214       0         0         0   2.0   1.0   0.5   0.0   2.0
# 4       1087222       0         0         0   1.0   3.0   0.0   0.0   2.0
# ...         ...     ...       ...       ...   ...   ...   ...   ...   ...
# 113354  1091072       1         0         1   7.0   7.0   7.0   7.0   7.0
# 113355  1091077       1         0         1   7.0   5.0   7.0   5.0   7.0
# 113356  1091104       1         0         1   5.0   5.0   5.0   5.0   5.0
# 113357  1091112       1         0         1   6.0   6.0   5.0   3.0   7.0
# 113358  1091115       1         0         1   6.0   6.0   5.0   3.0   7.0
#
#         S_wk  T_we  T_wk
# 0        0.5   4.0   2.0
# 1        1.0   4.0   1.0
# 2        0.5   3.0   1.0
# 3        1.0   4.0   3.0
# 4        1.0   2.0   1.0
# ...      ...   ...   ...
# 113354   7.0   7.0   7.0
# 113355   6.0   7.0   6.0
# 113356   5.0   5.0   5.0
# 113357   7.0   7.0   5.0
# 113358   5.0   6.0   5.0
#
# [113359 rows x 12 columns]

# %%
# Ensure plots render inline in the notebook
# %matplotlib inline
plt.scatter(df.S_we,df.T_we)
